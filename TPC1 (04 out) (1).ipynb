# %% [markdown]
# Beatriz Costa a95207
#
# TPC1: Jogo dos fósferos
#
# Instruções:
# O jogo começa com 21 fósferos, que são retirados à vez por dois jogadores. Cada jogador poderá retirar de cada vez um mínimo de um e um máximo de quatro fósferos. O vencedor será aquele que conseguir que fique apenas um fósfero no final.
#
# Neste jogo:
# Neste jogo pretende-se que um jogador jogue contra o computador de forma a que se este jogar em segundo lugar ganhe sempre e caso jogue em primeiro irá tentar apanhar o erro de raciocínio do oponente, apenas recorrendo à estrutura cíclica while .

# %%
def jogar(jogar_2, jogar_1):
    print("escolha se quer jogar em primeiro(insira1), ou em segundo lugar (insira 2)")
    x=int(input())
    if x==1:
        print("será o primeiro jogador")
        xx= (jogar_1)
    if x==2:
        print("será o segundo jogador")
        xx=(jogar_2)
iniciar= jogar(jogar_2, jogar_1)

# %%
def jogar_1():
    a=20
    print ([21,1])
    b=int(input("introduza 1,2,3 ou 4"))
        if b>=5:
            print("apenas se podem tirar 1,2,3 ou 4 fósferos")
        else:
            while a>10:
                a=a-b
                d=a-b
                print ([a,b])
                a=d
                if d>10 or d<6:
                    print ([d,b])
                   
                if d<=10 and d>6:
                    jogada=d-6
                    g=5-b
                    h=6-b
                    print ([d, jogada])
                    print ([6,b])
                    print ([h, g])
                    print ("perdeu o jogo")
                    print("para jogar novamente introduza j")
                        jo=input()
                        if jo==j:
                            return jogar(jogar_2 , jogar_1)
                if d==1:
                    print("ganhou o jogo")
                    print("para jogar novamente introduza j")
                    jo=input()
                    if jo==j:
                        return jogar(jogar_2 , jogar_1)
    
            if a==1:
                print("perdeu o jogo")
                print("para jogar novamente introduza j")
                jo=input()
                if jo==j:
                return jogar(jogar_2 , jogar_1)

# %%
def jogar_2():
    i=0
    a=21
    c=0
    while i<=5:
        b=int(input("introduza 1,2,3 ou 4"))
        if b>=5:
            print("apenas se podem tirar 1,2,3 ou 4 fósferos")
        else:
            a=a-b
            c=5-b
            a=a-c
            d=21-(5*i)
            print( [d,b])
            print( [a,c])
    if i>=6:
        print("para jogar novamente introduza j")
        jo=input()
        if jo==j:
            return jogar(jogar_2 , jogar_1)
